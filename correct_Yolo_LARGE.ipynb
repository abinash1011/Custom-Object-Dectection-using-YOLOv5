# %%
import PIL
print(PIL.__version__)
# Out:
# 9.5.0

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import random
import os
from tqdm import tqdm
import csv
import cv2
# %matplotlib inline

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in /home/ashutosh/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-9-3 Python-3.10.0 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
import urllib.request
urllib.request.urlretrieve('https://blog.finxter.com/wp-content/uploads/2022/04/greenland_01a.jpg',"img.jpg")
# Out:
# ('img.jpg', <http.client.HTTPMessage at 0x7fc7fb8568f0>)

# %%
img = "img.jpg"

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 360x640 7 persons, 1 boat
# Speed: 8.1ms pre-process, 94.5ms inference, 1.3ms NMS per image at shape (1, 3, 384, 640)

# %%
# !cd yolov5 && python train.py --img 640 --epochs 50 --data /home/ashutosh/work/od/yolov5/data/boards_class.yaml --weights yolov5l.pt --workers 8
# Out:
# train: weights=yolov5l.pt, cfg=, data=/home/ashutosh/work/od/yolov5/data/boards_class.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 19 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-198-g34c2187 Python-3.10.0 torch-2.0.1+cu117 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=6
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     59235  models.yolo.Detect                      [6, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 368 layers, 46165219 parameters, 46165219 gradients, 108.3 GFLOPs
#
# Transferred 607/613 items from yolov5l.pt
# optimizer: SGD(lr=0.01) with parameter groups 101 weight(decay=0.0), 104 weight(decay=0.0005), 104 bias
# train: Scanning /home/ashutosh/work/od/data2/labels.cache... 124 images, 0 backg
# val: Scanning /home/ashutosh/work/od/data2/labels.cache... 124 images, 0 backgro
#
# AutoAnchor: 3.27 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp25/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp25
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/49         0G     0.1203     0.0297    0.05346         28        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 1.900s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136   0.000617      0.103   0.000403   0.000109
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/49         0G     0.1021    0.03209     0.0556         37        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136    0.00274       0.67     0.0215    0.00631
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/49         0G    0.07845    0.03252    0.05366         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136    0.00333      0.912     0.0656     0.0262
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/49         0G    0.07543    0.03177    0.04968         33        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.891     0.0192      0.131     0.0549
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/49         0G    0.06644    0.02839    0.04479         27        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.175      0.121      0.175     0.0829
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/49         0G    0.06207     0.0275    0.04548         38        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.167      0.289      0.167      0.076
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/49         0G    0.05783    0.02338    0.04439         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.233      0.369      0.264       0.13
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/49         0G    0.06229     0.0222    0.04164         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.219      0.425      0.246      0.125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/49         0G     0.0569     0.0212    0.04004         36        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136       0.29      0.433      0.354      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/49         0G    0.06036    0.01897    0.04478         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.281        0.4      0.339      0.176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/49         0G    0.06108    0.01985    0.03851         36        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.359      0.425      0.384      0.231
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/49         0G    0.05575    0.02077    0.03859         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.417      0.438      0.432      0.214
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/49         0G    0.05036    0.01871    0.04197         25        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.517      0.502      0.486      0.297
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/49         0G    0.05228    0.01872    0.03493         28        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.503      0.491      0.528       0.28
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/49         0G    0.05174    0.01906    0.03244         31        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.608      0.674       0.68       0.41
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/49         0G    0.05756    0.01729    0.03208         29        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.555      0.673      0.708      0.329
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/49         0G    0.04481     0.0142    0.02898         27        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.503      0.637      0.594      0.267
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/49         0G    0.04918    0.01454    0.02951         33        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.614      0.744      0.749      0.506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/49         0G    0.04384    0.01671    0.02938         36        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.453      0.754      0.616      0.307
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/49         0G    0.04832    0.01541    0.02629         33        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.581      0.783      0.695      0.365
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/49         0G    0.04503    0.01499    0.02521         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.648      0.829      0.789      0.467
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/49         0G    0.04424    0.01473    0.02143         32        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.703      0.814      0.833      0.542
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/49         0G    0.03675     0.0143    0.02461         39        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.668      0.797      0.821      0.545
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/49         0G    0.04052    0.01233    0.02024         29        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.771      0.908        0.9      0.678
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/49         0G    0.03912    0.01279    0.01758         28        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.672      0.869      0.851      0.579
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/49         0G    0.03999    0.01233    0.01656         29        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.848      0.884      0.925      0.637
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/49         0G     0.0377    0.01291    0.01541         40        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.833      0.919      0.916      0.582
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/49         0G    0.03653    0.01276     0.0171         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.761      0.758      0.857      0.622
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/49         0G    0.03803    0.01301    0.01574         27        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.825      0.965      0.956      0.683
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/49         0G    0.03508    0.01283    0.01582         31        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.884      0.963      0.977      0.724
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/49         0G    0.03533    0.01217    0.01412         36        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.925      0.968      0.978      0.753
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/49         0G    0.03361    0.01234    0.01169         25        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.968      0.976      0.983      0.737
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/49         0G     0.0321    0.01223    0.01316         31        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.941      0.978      0.979      0.711
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/49         0G    0.03315    0.01114    0.01096         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.972      0.973      0.987      0.733
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/49         0G    0.03391    0.01155    0.01221         31        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.953      0.986      0.987      0.725
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/49         0G    0.02947    0.01152    0.01031         32        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.896       0.98      0.981      0.787
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/49         0G    0.03109    0.01122    0.01135         33        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.988       0.99      0.994      0.798
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/49         0G    0.02771    0.01058    0.01194         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.945      0.985      0.987      0.828
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/49         0G    0.02794    0.01043   0.009475         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.988      0.989      0.994      0.837
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/49         0G    0.02848    0.01076   0.009869         38        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.987       0.99      0.994      0.821
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/49         0G    0.02645    0.01142   0.009363         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.977      0.992      0.994      0.834
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/49         0G    0.02773    0.01009   0.009874         29        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.986      0.993      0.995      0.866
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/49         0G    0.02267    0.01066     0.0102         36        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.985      0.993      0.995      0.848
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/49         0G    0.02506    0.01088   0.008876         31        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.983      0.994      0.995      0.876
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/49         0G    0.02163    0.01017   0.007384         26        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.984      0.994      0.995      0.886
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/49         0G    0.02208   0.009536   0.006896         35        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.983      0.994      0.994      0.887
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/49         0G    0.02406   0.009353   0.009715         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.984      0.994      0.994      0.883
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/49         0G    0.02632    0.01028   0.008606         30        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.985      0.993      0.995      0.898
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/49         0G    0.02018    0.01027   0.007319         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.991      0.987      0.995      0.901
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/49         0G    0.02169   0.009413   0.007615         34        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.993      0.987      0.995      0.903
#
# 50 epochs completed in 2.139 hours.
# Optimizer stripped from runs/train/exp25/weights/last.pt, 92.9MB
# Optimizer stripped from runs/train/exp25/weights/best.pt, 92.9MB
#
# Validating runs/train/exp25/weights/best.pt...
# Fusing layers...
# Model summary: 267 layers, 46135203 parameters, 0 gradients, 107.7 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        124        136      0.993      0.987      0.995      0.903
#            Arduino Uno        124         28      0.997          1      0.995      0.937
# Arduino Nano BLE Sense        124         23          1      0.978      0.995       0.84
#                 ESP 32        124         21          1      0.984      0.995      0.907
#     Nvidia Jetson Nano        124         23       0.99          1      0.995      0.908
#           Raspberry Pi        124         24      0.983      0.958      0.993      0.921
#           STM32 Nucleo        124         17      0.987          1      0.995      0.906
# Results saved to runs/train/exp25

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp25/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/ashutosh/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-9-15 Python-3.10.0 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# Model summary: 267 layers, 46135203 parameters, 0 gradients, 107.7 GFLOPs
# Adding AutoShape...

# %%
def get_random_file_paths(directory, num_files):
    file_list = [os.path.join(directory, file) for file in os.listdir(directory) if os.path.isfile(os.path.join(directory, file))]
    if not file_list:
        raise ValueError("No files found in the directory.")

    return random.sample(file_list, num_files)

# %%
test_img = "test3.jpg"
# test_img = get_random_file_paths("data/images/", 1)

test_img = test_img if type(test_img) == str else test_img[0]

results = model(test_img)

results.print()
# Out:
# image 1/1: 3456x4608 1 Arduino Uno, 1 Arduino Nano BLE Sense, 1 ESP 32, 1 Nvidia Jetson Nano, 1 Raspberry Pi, 1 STM32 Nucleo
# Speed: 124.3ms pre-process, 269.3ms inference, 0.8ms NMS per image at shape (1, 3, 480, 640)

# %%
plt.imshow(np.squeeze(results.render()))
plt.title(test_img[0].split("/")[-1])
plt.savefig("det4.jpg", dpi=600)
plt.show()

# %%
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
num_images_per_row = 6
num_rows = 6

directory_path = "data/images/"
random_file_paths = get_random_file_paths(directory_path, num_images_per_row * num_rows)

fig, axes = plt.subplots(num_rows, num_images_per_row, figsize=(12, 12))

for i, file_path in enumerate(random_file_paths):
    results = model(file_path)
    ax = axes[i // num_images_per_row, i % num_images_per_row]
    ax.imshow(np.squeeze(results.render()))
    ax.set_title(file_path.split("/")[-1])
    ax.axis("off")

plt.tight_layout()
plt.show()

# %%
model2 = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp6/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/ashutosh/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-8-5 Python-3.10.0 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7066762 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
test_img = "data/images/mix6.jpg"
# test_img = get_random_file_paths("data/images/", 1)

test_img = test_img if type(test_img) == str else test_img[0]

results = model2(test_img)
results.print()
plt.imshow(np.squeeze(results.render()))
# Out:
# image 1/1: 480x640 1 Arduino Uno, 1 Nvidia Jetson Nano
# Speed: 5.0ms pre-process, 64.6ms inference, 0.8ms NMS per image at shape (1, 3, 480, 640)

# %%
results.names
# Out:
# {0: 'dog',
#  1: 'person',
#  2: 'cat',
#  3: 'tv',
#  4: 'car',
#  5: 'meatballs',
#  6: 'marinara sauce',
#  7: 'tomato soup',
#  8: 'chicken noodle soup',
#  9: 'french onion soup',
#  10: 'chicken breast',
#  11: 'ribs',
#  12: 'pulled pork',
#  13: 'hamburger',
#  14: 'cavity',
#  15: 'Arduino Uno',
#  16: 'Arduino Nano BLE Sense',
#  17: 'ESP 32',
#  18: 'Nvidia Jetson Nano',
#  19: 'Raspberry Pi',
#  20: 'STM32 Nucleo'}

# %%
highest_confidence_index = results.pred[0][:, -2].argmax().item()
results.names[int(results.pred[0][highest_confidence_index][-1])]
# Out:
# 'STM32 Nucleo'

# %%
for i in range(1,17):
    print('"data/images/stm'+str(i)+'.jpg", "STM32 Nucleo",')
# Out:
# "data/images/stm1.jpg", "STM32 Nucleo",
# "data/images/stm2.jpg", "STM32 Nucleo",
# "data/images/stm3.jpg", "STM32 Nucleo",
# "data/images/stm4.jpg", "STM32 Nucleo",
# "data/images/stm5.jpg", "STM32 Nucleo",
# "data/images/stm6.jpg", "STM32 Nucleo",
# "data/images/stm7.jpg", "STM32 Nucleo",
# "data/images/stm8.jpg", "STM32 Nucleo",
# "data/images/stm9.jpg", "STM32 Nucleo",
# "data/images/stm10.jpg", "STM32 Nucleo",
# "data/images/stm11.jpg", "STM32 Nucleo",
# "data/images/stm12.jpg", "STM32 Nucleo",
# "data/images/stm13.jpg", "STM32 Nucleo",
# "data/images/stm14.jpg", "STM32 Nucleo",
# "data/images/stm15.jpg", "STM32 Nucleo",
# "data/images/stm16.jpg", "STM32 Nucleo",

# %%
image_paths = []
ground_truth_labels = []
with open('test_data.csv', newline='') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        image_paths.append(row[0].strip())  # Remove leading/trailing spaces
        ground_truth_labels.append(row[1].strip())

# %%
print(image_paths)
# Out:
# ['data/images/aruno1.jpg', 'data/images/aruno2.jpg', 'data/images/aruno3.jpg', 'data/images/aruno4.jpg', 'data/images/aruno5.jpg', 'data/images/aruno6.jpg', 'data/images/aruno7.jpg', 'data/images/aruno8.jpg', 'data/images/aruno9.jpg', 'data/images/aruno10.jpg', 'data/images/aruno11.jpg', 'data/images/aruno12.jpg', 'data/images/aruno13.jpg', 'data/images/aruno14.jpg', 'data/images/aruno15.jpg', 'data/images/aruno16.jpg', 'data/images/aruno17.jpg', 'data/images/aruno18.jpg', 'data/images/aruno19.jpg', 'data/images/aruno20.jpg', 'data/images/ble1.jpg', 'data/images/ble2.jpg', 'data/images/ble3.jpg', 'data/images/ble4.jpg', 'data/images/ble5.jpg', 'data/images/ble6.jpg', 'data/images/ble7.jpg', 'data/images/ble8.jpg', 'data/images/ble9.jpg', 'data/images/ble10.jpg', 'data/images/ble11.jpg', 'data/images/ble12.jpg', 'data/images/ble13.jpg', 'data/images/ble14.jpg', 'data/images/ble15.jpg', 'data/images/ble16.jpg', 'data/images/ble17.jpg', 'data/images/ble18.jpg', 'data/images/ble19.jpg', 'data/images/ble20.jpg', 'data/images/ble21.jpg', 'data/images/esp1.jpg', 'data/images/esp2.jpg', 'data/images/esp3.jpg', 'data/images/esp4.jpg', 'data/images/esp5.jpg', 'data/images/esp6.jpg', 'data/images/esp7.jpg', 'data/images/esp8.jpg', 'data/images/esp9.jpg', 'data/images/esp10.jpg', 'data/images/esp11.jpg', 'data/images/esp12.jpg', 'data/images/esp13.jpg', 'data/images/esp14.jpg', 'data/images/esp15.jpg', 'data/images/esp16.jpg', 'data/images/esp17.jpg', 'data/images/esp18.jpg', 'data/images/esp19.jpg', 'data/images/jet1.jpg', 'data/images/jet2.jpg', 'data/images/jet3.jpg', 'data/images/jet4.jpg', 'data/images/jet5.jpg', 'data/images/jet6.jpg', 'data/images/jet7.jpg', 'data/images/jet8.jpg', 'data/images/jet9.jpg', 'data/images/jet10.jpg', 'data/images/jet11.jpg', 'data/images/jet12.jpg', 'data/images/jet13.jpg', 'data/images/jet14.jpg', 'data/images/jet15.jpg', 'data/images/jet16.jpg', 'data/images/jet17.jpg', 'data/images/jet18.jpg', 'data/images/jet19.jpg', 'data/images/jet20.jpg', 'data/images/ras1.jpg', 'data/images/ras2.jpg', 'data/images/ras3.jpg', 'data/images/ras4.jpg', 'data/images/ras5.jpg', 'data/images/ras6.jpg', 'data/images/ras7.jpg', 'data/images/ras8.jpg', 'data/images/ras9.jpg', 'data/images/ras10.jpg', 'data/images/ras11.jpg', 'data/images/ras12.jpg', 'data/images/ras13.jpg', 'data/images/ras14.jpg', 'data/images/ras15.jpg', 'data/images/ras16.jpg', 'data/images/ras17.jpg', 'data/images/ras18.jpg', 'data/images/stm1.jpg', 'data/images/stm2.jpg', 'data/images/stm3.jpg', 'data/images/stm4.jpg', 'data/images/stm5.jpg', 'data/images/stm6.jpg', 'data/images/stm7.jpg', 'data/images/stm8.jpg', 'data/images/stm9.jpg', 'data/images/stm10.jpg', 'data/images/stm11.jpg', 'data/images/stm12.jpg', 'data/images/stm13.jpg', 'data/images/stm14.jpg', 'data/images/stm15.jpg', 'data/images/stm16.jpg']

# %%
correct_predictions = 0
total_images = len(image_paths)

for image_path, ground_truth_label in tqdm(zip(image_paths, ground_truth_labels)):
    results = model(image_path)

    # Check if any objects were detected
    if len(results.pred[0]) == 0:
        continue

    # Find the index of the highest confidence score
    highest_confidence_index = results.pred[0][:, -2].argmax().item()

    # Get the corresponding class label for the highest confidence prediction
    predicted_label = results.names[int(results.pred[0][highest_confidence_index][-1])]
    # print(predicted_label)
    # print(ground_truth_label)
    # print("-----------------------")
    if predicted_label == ground_truth_label:
        correct_predictions += 1

accuracy = (correct_predictions / total_images) * 100
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 correct_predictions = 0
# ----> 2 total_images = len(image_paths)
#       4 for image_path, ground_truth_label in tqdm(zip(image_paths, ground_truth_labels)):
#       5     results = model(image_path)
#
# NameError: name 'image_paths' is not defined

# %%
from sklearn
# Out:
# 104

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@144151.058] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@144151.058] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range

# %%
import csv

input_file = "test_data.csv"
output_file = "output.csv"

modified_data = []

with open(input_file, "r") as csv_file:
    reader = csv.reader(csv_file)
    for row in reader:
        path = row[0]
        label = row[1].strip('"') if len(row) > 1 else ""
        modified_data.append((path, label))

with open(output_file, "w", newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter='\t')  # Specify the delimiter as '\t' for tab separation
    writer.writerows(modified_data)

# %%
import os
import torch

# Get the model's state dictionary
model_state_dict = model.state_dict()

# Calculate the size of the model in bytes
model_size_bytes = sum(p.numel() * p.element_size() for p in model_state_dict.values())

# Convert to kilobytes (KB) and megabytes (MB)
model_size_kb = model_size_bytes / 1024
model_size_mb = model_size_kb / 1024

print(f"Model size: {model_size_bytes} bytes ({model_size_kb:.2f} KB or {model_size_mb:.2f} MB)")
# Out:
# Model size: 184540884 bytes (180215.71 KB or 175.99 MB)

# %%
import torch
from torch.quantization import quantize_dynamic

# Quantize the model (PTQ for both weights and activations)
quantized_model = quantize_dynamic(model, dtype=torch.qint8)

# Assuming you have a quantized model named 'quantized_model'
torch.save(quantized_model.state_dict(), 'quantized_yolov5.pth')
